# %% [markdown]
#    <H1>Deriverable 1: Retrieve Weather Data<h1>

# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6b9041390b43daeead997c989a5d2b1

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
            # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})
                          #"Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | juba
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | grand-santi
# Processing Record 4 of Set 1 | osmena
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | klaksvik
# Processing Record 8 of Set 1 | kamenka
# Processing Record 9 of Set 1 | boyabat
# Processing Record 10 of Set 1 | bethel
# Processing Record 11 of Set 1 | sambava
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | aklavik
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | bullhead city
# Processing Record 16 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | torbay
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | wattegama
# Processing Record 22 of Set 1 | lima
# Processing Record 23 of Set 1 | kruisfontein
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | fairbanks
# Processing Record 26 of Set 1 | sur
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | khatanga
# Processing Record 29 of Set 1 | omboue
# Processing Record 30 of Set 1 | forbes
# Processing Record 31 of Set 1 | itacarambi
# Processing Record 32 of Set 1 | ribeira grande
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | diego de almagro
# Processing Record 35 of Set 1 | poum
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | pevek
# Processing Record 38 of Set 1 | karimganj
# Processing Record 39 of Set 1 | yara
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | tilichiki
# Processing Record 42 of Set 1 | peniche
# Processing Record 43 of Set 1 | sao joao da barra
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | tambun
# Processing Record 46 of Set 1 | nanortalik
# Processing Record 47 of Set 1 | shebunino
# Processing Record 48 of Set 1 | paamiut
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | saldanha
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | northam
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | lasa
# Processing Record 6 of Set 2 | saskylakh
# Processing Record 7 of Set 2 | chuy
# Processing Record 8 of Set 2 | codrington
# Processing Record 9 of Set 2 | bana
# Processing Record 10 of Set 2 | tres palos
# Processing Record 11 of Set 2 | naze
# Processing Record 12 of Set 2 | carnarvon
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | lixourion
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | fulacunda
# City not found. Skipping...
# Processing Record 18 of Set 2 | benguela
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | airai
# Processing Record 21 of Set 2 | nata
# Processing Record 22 of Set 2 | sovetskiy
# Processing Record 23 of Set 2 | phangnga
# Processing Record 24 of Set 2 | waipawa
# Processing Record 25 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | canico
# Processing Record 28 of Set 2 | poronaysk
# Processing Record 29 of Set 2 | leticia
# Processing Record 30 of Set 2 | zhanakorgan
# Processing Record 31 of Set 2 | kloulklubed
# Processing Record 32 of Set 2 | guaymas
# Processing Record 33 of Set 2 | cockburn town
# Processing Record 34 of Set 2 | fevralsk
# City not found. Skipping...
# Processing Record 35 of Set 2 | punta arenas
# Processing Record 36 of Set 2 | constitucion
# Processing Record 37 of Set 2 | port elizabeth
# Processing Record 38 of Set 2 | opuwo
# Processing Record 39 of Set 2 | mitsamiouli
# Processing Record 40 of Set 2 | port hedland
# Processing Record 41 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 2 | hirara
# Processing Record 43 of Set 2 | cape town
# Processing Record 44 of Set 2 | samarai
# Processing Record 45 of Set 2 | jiuquan
# Processing Record 46 of Set 2 | victor harbor
# Processing Record 47 of Set 2 | georgetown
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 2 | saint-philippe
# Processing Record 1 of Set 3 | yellowknife
# Processing Record 2 of Set 3 | umm lajj
# Processing Record 3 of Set 3 | cidreira
# Processing Record 4 of Set 3 | cacu
# Processing Record 5 of Set 3 | hermanus
# Processing Record 6 of Set 3 | axim
# Processing Record 7 of Set 3 | yulara
# Processing Record 8 of Set 3 | porto novo
# Processing Record 9 of Set 3 | pangody
# Processing Record 10 of Set 3 | port-cartier
# Processing Record 11 of Set 3 | vung tau
# Processing Record 12 of Set 3 | conceicao do araguaia
# Processing Record 13 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 3 | oksfjord
# Processing Record 15 of Set 3 | marawi
# Processing Record 16 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 3 | nikolskoye
# Processing Record 18 of Set 3 | chiredzi
# Processing Record 19 of Set 3 | coruripe
# Processing Record 20 of Set 3 | tahta
# Processing Record 21 of Set 3 | taseyevo
# Processing Record 22 of Set 3 | avera
# Processing Record 23 of Set 3 | provideniya
# Processing Record 24 of Set 3 | puksoozero
# Processing Record 25 of Set 3 | chernigovka
# Processing Record 26 of Set 3 | iskateley
# Processing Record 27 of Set 3 | hualmay
# Processing Record 28 of Set 3 | kasongo-lunda
# Processing Record 29 of Set 3 | avarua
# Processing Record 30 of Set 3 | bambous virieux
# Processing Record 31 of Set 3 | kaitangata
# Processing Record 32 of Set 3 | catalina
# Processing Record 33 of Set 3 | geraldton
# Processing Record 34 of Set 3 | port lincoln
# Processing Record 35 of Set 3 | taltal
# Processing Record 36 of Set 3 | arraial do cabo
# Processing Record 37 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 3 | oranjemund
# Processing Record 39 of Set 3 | college
# Processing Record 40 of Set 3 | karangampel
# Processing Record 41 of Set 3 | wanxian
# Processing Record 42 of Set 3 | hami
# Processing Record 43 of Set 3 | ravar
# Processing Record 44 of Set 3 | flin flon
# Processing Record 45 of Set 3 | komsomolskiy
# Processing Record 46 of Set 3 | san carlos de bariloche
# Processing Record 47 of Set 3 | tiksi
# Processing Record 48 of Set 3 | vila franca do campo
# Processing Record 49 of Set 3 | begunitsy
# Processing Record 50 of Set 3 | wanlaweyn
# Processing Record 1 of Set 4 | shimoda
# Processing Record 2 of Set 4 | doha
# Processing Record 3 of Set 4 | balingasay
# Processing Record 4 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 4 | iqaluit
# Processing Record 6 of Set 4 | severo-kurilsk
# Processing Record 7 of Set 4 | jinxiang
# Processing Record 8 of Set 4 | gat
# Processing Record 9 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 4 | dunedin
# Processing Record 11 of Set 4 | beringovskiy
# Processing Record 12 of Set 4 | coahuayana
# Processing Record 13 of Set 4 | souillac
# Processing Record 14 of Set 4 | kavieng
# Processing Record 15 of Set 4 | coatlan
# City not found. Skipping...
# Processing Record 16 of Set 4 | faanui
# Processing Record 17 of Set 4 | luderitz
# Processing Record 18 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 4 | lebu
# Processing Record 20 of Set 4 | richards bay
# Processing Record 21 of Set 4 | kaduqli
# Processing Record 22 of Set 4 | palana
# Processing Record 23 of Set 4 | kamariotissa
# Processing Record 24 of Set 4 | kempele
# Processing Record 25 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 4 | barranca
# Processing Record 27 of Set 4 | bisignano
# Processing Record 28 of Set 4 | russell
# Processing Record 29 of Set 4 | scarborough
# Processing Record 30 of Set 4 | hanzhong
# Processing Record 31 of Set 4 | adwa
# Processing Record 32 of Set 4 | east london
# Processing Record 33 of Set 4 | illapel
# Processing Record 34 of Set 4 | kyra
# Processing Record 35 of Set 4 | turukhansk
# Processing Record 36 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 37 of Set 4 | taoudenni
# Processing Record 38 of Set 4 | tripoli
# Processing Record 39 of Set 4 | alihe
# Processing Record 40 of Set 4 | whitianga
# Processing Record 41 of Set 4 | barrow
# Processing Record 42 of Set 4 | chapais
# Processing Record 43 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 4 | kodiak
# Processing Record 45 of Set 4 | crib point
# Processing Record 46 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 47 of Set 4 | aripuana
# Processing Record 48 of Set 4 | itarema
# Processing Record 49 of Set 4 | basoko
# Processing Record 50 of Set 4 | port hardy
# Processing Record 1 of Set 5 | balykshi
# Processing Record 2 of Set 5 | roald
# Processing Record 3 of Set 5 | edd
# Processing Record 4 of Set 5 | dolinsk
# Processing Record 5 of Set 5 | turtas
# Processing Record 6 of Set 5 | kalmunai
# Processing Record 7 of Set 5 | lavrentiya
# Processing Record 8 of Set 5 | erdenet
# Processing Record 9 of Set 5 | bulgan
# Processing Record 10 of Set 5 | soyo
# Processing Record 11 of Set 5 | vire
# Processing Record 12 of Set 5 | mashhad
# Processing Record 13 of Set 5 | dallas
# Processing Record 14 of Set 5 | ponta delgada
# Processing Record 15 of Set 5 | tshikapa
# Processing Record 16 of Set 5 | chimore
# Processing Record 17 of Set 5 | abalak
# Processing Record 18 of Set 5 | mar del plata
# Processing Record 19 of Set 5 | warka
# Processing Record 20 of Set 5 | isangel
# Processing Record 21 of Set 5 | grandview
# Processing Record 22 of Set 5 | buraydah
# Processing Record 23 of Set 5 | khani
# Processing Record 24 of Set 5 | lorengau
# Processing Record 25 of Set 5 | port augusta
# Processing Record 26 of Set 5 | yaan
# Processing Record 27 of Set 5 | tual
# Processing Record 28 of Set 5 | vao
# Processing Record 29 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 5 | cajuru
# Processing Record 31 of Set 5 | ayoquezco
# City not found. Skipping...
# Processing Record 32 of Set 5 | pacific grove
# Processing Record 33 of Set 5 | kopyevo
# City not found. Skipping...
# Processing Record 34 of Set 5 | mount gambier
# Processing Record 35 of Set 5 | inhambane
# Processing Record 36 of Set 5 | martil
# Processing Record 37 of Set 5 | beckley
# Processing Record 38 of Set 5 | abu samrah
# Processing Record 39 of Set 5 | rockport
# Processing Record 40 of Set 5 | andenes
# Processing Record 41 of Set 5 | pacifica
# Processing Record 42 of Set 5 | zdunska wola
# Processing Record 43 of Set 5 | el ejido
# Processing Record 44 of Set 5 | tigil
# Processing Record 45 of Set 5 | saint george
# Processing Record 46 of Set 5 | norman wells
# Processing Record 47 of Set 5 | bathsheba
# Processing Record 48 of Set 5 | gumdag
# Processing Record 49 of Set 5 | cajaruro
# Processing Record 50 of Set 5 | upata
# Processing Record 1 of Set 6 | alyangula
# Processing Record 2 of Set 6 | pangnirtung
# Processing Record 3 of Set 6 | san cristobal
# Processing Record 4 of Set 6 | touros
# Processing Record 5 of Set 6 | okha
# Processing Record 6 of Set 6 | saint-denis
# Processing Record 7 of Set 6 | zharkent
# Processing Record 8 of Set 6 | dalvik
# Processing Record 9 of Set 6 | bonavista
# Processing Record 10 of Set 6 | dukat
# Processing Record 11 of Set 6 | valparaiso
# Processing Record 12 of Set 6 | ahipara
# Processing Record 13 of Set 6 | te anau
# Processing Record 14 of Set 6 | chulman
# Processing Record 15 of Set 6 | marechal candido rondon
# Processing Record 16 of Set 6 | burnie
# Processing Record 17 of Set 6 | gobabis
# Processing Record 18 of Set 6 | vardo
# Processing Record 19 of Set 6 | beipiao
# Processing Record 20 of Set 6 | alofi
# Processing Record 21 of Set 6 | ballina
# Processing Record 22 of Set 6 | mahebourg
# Processing Record 23 of Set 6 | cody
# Processing Record 24 of Set 6 | lagoa
# Processing Record 25 of Set 6 | antofagasta
# Processing Record 26 of Set 6 | flinders
# Processing Record 27 of Set 6 | slonim
# Processing Record 28 of Set 6 | preobrazheniye
# Processing Record 29 of Set 6 | teya
# Processing Record 30 of Set 6 | bereda
# Processing Record 31 of Set 6 | cabo san lucas
# Processing Record 32 of Set 6 | ambilobe
# Processing Record 33 of Set 6 | santiago de chuco
# Processing Record 34 of Set 6 | kot diji
# Processing Record 35 of Set 6 | qaanaaq
# Processing Record 36 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 6 | ponta do sol
# Processing Record 38 of Set 6 | terney
# Processing Record 39 of Set 6 | yumen
# Processing Record 40 of Set 6 | goundam
# Processing Record 41 of Set 6 | charters towers
# Processing Record 42 of Set 6 | solnechnyy
# Processing Record 43 of Set 6 | bluff
# Processing Record 44 of Set 6 | nishihara
# Processing Record 45 of Set 6 | jacmel
# Processing Record 46 of Set 6 | necochea
# Processing Record 47 of Set 6 | tuatapere
# Processing Record 48 of Set 6 | betioky
# Processing Record 49 of Set 6 | bilma
# Processing Record 50 of Set 6 | fort nelson
# Processing Record 1 of Set 7 | susangerd
# Processing Record 2 of Set 7 | qui nhon
# Processing Record 3 of Set 7 | sola
# Processing Record 4 of Set 7 | dingle
# Processing Record 5 of Set 7 | santa luzia
# Processing Record 6 of Set 7 | sterling
# Processing Record 7 of Set 7 | markova
# Processing Record 8 of Set 7 | moose factory
# Processing Record 9 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 7 | moree
# Processing Record 11 of Set 7 | velyka kisnytsya
# City not found. Skipping...
# Processing Record 12 of Set 7 | port macquarie
# Processing Record 13 of Set 7 | narsaq
# Processing Record 14 of Set 7 | lata
# Processing Record 15 of Set 7 | quatre cocos
# Processing Record 16 of Set 7 | gombong
# Processing Record 17 of Set 7 | negombo
# Processing Record 18 of Set 7 | ingham
# Processing Record 19 of Set 7 | puerto colombia
# Processing Record 20 of Set 7 | dalbandin
# Processing Record 21 of Set 7 | kidal
# Processing Record 22 of Set 7 | nizhnevartovsk
# Processing Record 23 of Set 7 | intipuca
# Processing Record 24 of Set 7 | smidovich
# Processing Record 25 of Set 7 | pa sang
# Processing Record 26 of Set 7 | birnin kebbi
# Processing Record 27 of Set 7 | vanavara
# Processing Record 28 of Set 7 | westport
# Processing Record 29 of Set 7 | berlevag
# Processing Record 30 of Set 7 | maposeni
# Processing Record 31 of Set 7 | umm kaddadah
# Processing Record 32 of Set 7 | dakar
# Processing Record 33 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 7 | sundumbili
# Processing Record 35 of Set 7 | marovoay
# Processing Record 36 of Set 7 | kyshtovka
# Processing Record 37 of Set 7 | hasaki
# Processing Record 38 of Set 7 | gboko
# Processing Record 39 of Set 7 | sorland
# Processing Record 40 of Set 7 | bengkulu
# Processing Record 41 of Set 7 | nara
# Processing Record 42 of Set 7 | san andres
# Processing Record 43 of Set 7 | longyearbyen
# Processing Record 44 of Set 7 | high rock
# Processing Record 45 of Set 7 | pingliang
# Processing Record 46 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 7 | coihaique
# Processing Record 48 of Set 7 | qaqortoq
# Processing Record 49 of Set 7 | san luis de la paz
# Processing Record 50 of Set 7 | takhtamygda
# Processing Record 1 of Set 8 | xiangxiang
# Processing Record 2 of Set 8 | sinjai
# Processing Record 3 of Set 8 | copiapo
# Processing Record 4 of Set 8 | dikson
# Processing Record 5 of Set 8 | sao filipe
# Processing Record 6 of Set 8 | ilulissat
# Processing Record 7 of Set 8 | gorele
# Processing Record 8 of Set 8 | moundsville
# Processing Record 9 of Set 8 | mabaruma
# Processing Record 10 of Set 8 | ilebo
# Processing Record 11 of Set 8 | korla
# Processing Record 12 of Set 8 | banswara
# Processing Record 13 of Set 8 | victoria
# Processing Record 14 of Set 8 | tres arroyos
# Processing Record 15 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 8 | roma
# Processing Record 17 of Set 8 | labuhan
# Processing Record 18 of Set 8 | bagdarin
# Processing Record 19 of Set 8 | cururupu
# Processing Record 20 of Set 8 | udarnyy
# Processing Record 21 of Set 8 | san patricio
# Processing Record 22 of Set 8 | miajadas
# Processing Record 23 of Set 8 | mumford
# Processing Record 24 of Set 8 | kavaratti
# Processing Record 25 of Set 8 | yunjinghong
# City not found. Skipping...
# Processing Record 26 of Set 8 | nouadhibou
# Processing Record 27 of Set 8 | la ronge
# Processing Record 28 of Set 8 | hwange
# Processing Record 29 of Set 8 | neuquen
# Processing Record 30 of Set 8 | zhanaozen
# Processing Record 31 of Set 8 | ixtapa
# Processing Record 32 of Set 8 | mukhen
# Processing Record 33 of Set 8 | rorvik
# Processing Record 34 of Set 8 | yantal
# Processing Record 35 of Set 8 | parambu
# Processing Record 36 of Set 8 | guerrero negro
# Processing Record 37 of Set 8 | prado
# Processing Record 38 of Set 8 | muravlenko
# Processing Record 39 of Set 8 | faya
# Processing Record 40 of Set 8 | tautira
# Processing Record 41 of Set 8 | padang
# Processing Record 42 of Set 8 | niono
# Processing Record 43 of Set 8 | ensley
# Processing Record 44 of Set 8 | hoquiam
# Processing Record 45 of Set 8 | moroni
# Processing Record 46 of Set 8 | aguimes
# Processing Record 47 of Set 8 | zhuhai
# Processing Record 48 of Set 8 | puerto del rosario
# Processing Record 49 of Set 8 | chitral
# Processing Record 50 of Set 8 | kismayo
# Processing Record 1 of Set 9 | san policarpo
# Processing Record 2 of Set 9 | bafata
# Processing Record 3 of Set 9 | hambantota
# Processing Record 4 of Set 9 | banikoara
# Processing Record 5 of Set 9 | susehri
# Processing Record 6 of Set 9 | el alto
# Processing Record 7 of Set 9 | challapata
# Processing Record 8 of Set 9 | kiunga
# Processing Record 9 of Set 9 | rudsar
# Processing Record 10 of Set 9 | tura
# Processing Record 11 of Set 9 | polunochnoye
# Processing Record 12 of Set 9 | mardin
# Processing Record 13 of Set 9 | leningradskiy
# Processing Record 14 of Set 9 | hofn
# Processing Record 15 of Set 9 | mbarara
# Processing Record 16 of Set 9 | nantucket
# Processing Record 17 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 9 | boca do acre
# Processing Record 19 of Set 9 | pandan
# Processing Record 20 of Set 9 | ancud
# Processing Record 21 of Set 9 | fiche
# Processing Record 22 of Set 9 | yar-sale
# Processing Record 23 of Set 9 | acapulco
# Processing Record 24 of Set 9 | sierpc
# Processing Record 25 of Set 9 | saravan
# Processing Record 26 of Set 9 | pathein
# Processing Record 27 of Set 9 | abu zabad
# Processing Record 28 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 29 of Set 9 | hornepayne
# Processing Record 30 of Set 9 | goderich
# Processing Record 31 of Set 9 | fuerte olimpo
# Processing Record 32 of Set 9 | lyngseidet
# Processing Record 33 of Set 9 | san miguel
# Processing Record 34 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 9 | camacha
# Processing Record 36 of Set 9 | okakarara
# Processing Record 37 of Set 9 | pinawa
# Processing Record 38 of Set 9 | saint-joseph
# Processing Record 39 of Set 9 | aketi
# Processing Record 40 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 9 | quetta
# Processing Record 42 of Set 9 | husavik
# Processing Record 43 of Set 9 | batticaloa
# Processing Record 44 of Set 9 | atar
# Processing Record 45 of Set 9 | kirakira
# Processing Record 46 of Set 9 | namtsy
# Processing Record 47 of Set 9 | bandundu
# Processing Record 48 of Set 9 | esperance
# Processing Record 49 of Set 9 | sulphur
# Processing Record 50 of Set 9 | shiyan
# Processing Record 1 of Set 10 | deputatskiy
# Processing Record 2 of Set 10 | talara
# Processing Record 3 of Set 10 | salina
# Processing Record 4 of Set 10 | ambon
# Processing Record 5 of Set 10 | achern
# Processing Record 6 of Set 10 | chipinge
# Processing Record 7 of Set 10 | jutai
# Processing Record 8 of Set 10 | burgeo
# Processing Record 9 of Set 10 | mercedes
# Processing Record 10 of Set 10 | vuktyl
# Processing Record 11 of Set 10 | barcelona
# Processing Record 12 of Set 10 | buin
# Processing Record 13 of Set 10 | talnakh
# Processing Record 14 of Set 10 | grand forks
# Processing Record 15 of Set 10 | sabang
# Processing Record 16 of Set 10 | tiarei
# Processing Record 17 of Set 10 | amuntai
# Processing Record 18 of Set 10 | pietroasa
# Processing Record 19 of Set 10 | tamandare
# Processing Record 20 of Set 10 | laguna
# Processing Record 21 of Set 10 | rocha
# Processing Record 22 of Set 10 | bitung
# Processing Record 23 of Set 10 | half moon bay
# Processing Record 24 of Set 10 | rodrigues alves
# Processing Record 25 of Set 10 | narodychi
# Processing Record 26 of Set 10 | houma
# Processing Record 27 of Set 10 | prince rupert
# Processing Record 28 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 29 of Set 10 | yambio
# Processing Record 30 of Set 10 | batagay-alyta
# Processing Record 31 of Set 10 | ketchikan
# Processing Record 32 of Set 10 | capaci
# Processing Record 33 of Set 10 | macara
# Processing Record 34 of Set 10 | maneadero
# Processing Record 35 of Set 10 | krasnoselkup
# Processing Record 36 of Set 10 | sontra
# Processing Record 37 of Set 10 | nome
# Processing Record 38 of Set 10 | high level
# Processing Record 39 of Set 10 | witu
# Processing Record 40 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 10 | san quintin
# Processing Record 42 of Set 10 | alice
# Processing Record 43 of Set 10 | atbasar
# Processing Record 44 of Set 10 | akyab
# Processing Record 45 of Set 10 | los llanos de aridane
# Processing Record 46 of Set 10 | odweyne
# Processing Record 47 of Set 10 | najran
# Processing Record 48 of Set 10 | ucluelet
# Processing Record 49 of Set 10 | ylivieska
# Processing Record 50 of Set 10 | boshnyakovo
# Processing Record 1 of Set 11 | nalut
# Processing Record 2 of Set 11 | sydney
# Processing Record 3 of Set 11 | karsun
# Processing Record 4 of Set 11 | redmond
# Processing Record 5 of Set 11 | clyde river
# Processing Record 6 of Set 11 | ugoofaaru
# Processing Record 7 of Set 11 | nabire
# Processing Record 8 of Set 11 | porirua
# Processing Record 9 of Set 11 | haines junction
# Processing Record 10 of Set 11 | krasnoarmeysk
# Processing Record 11 of Set 11 | sao felix do xingu
# Processing Record 12 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 13 of Set 11 | sitka
# Processing Record 14 of Set 11 | chebsara
# Processing Record 15 of Set 11 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 16 of Set 11 | kununurra
# Processing Record 17 of Set 11 | tevaitoa
# Processing Record 18 of Set 11 | coquimbo
# Processing Record 19 of Set 11 | havelock
# Processing Record 20 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 11 | rosarito
# Processing Record 22 of Set 11 | hovd
# Processing Record 23 of Set 11 | ostrovnoy
# Processing Record 24 of Set 11 | tarko-sale
# Processing Record 25 of Set 11 | cayenne
# Processing Record 26 of Set 11 | luancheng
# Processing Record 27 of Set 11 | eckernforde
# Processing Record 28 of Set 11 | cabedelo
# Processing Record 29 of Set 11 | dubovskoye
# Processing Record 30 of Set 11 | bowen
# Processing Record 31 of Set 11 | calvinia
# Processing Record 32 of Set 11 | shalya
# Processing Record 33 of Set 11 | yerbogachen
# Processing Record 34 of Set 11 | caravelas
# Processing Record 35 of Set 11 | okhotsk
# Processing Record 36 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 11 | anadyr
# Processing Record 38 of Set 11 | sulangan
# Processing Record 39 of Set 11 | matara
# Processing Record 40 of Set 11 | shingu
# Processing Record 41 of Set 11 | sinnamary
# Processing Record 42 of Set 11 | noumea
# Processing Record 43 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 44 of Set 11 | rantepao
# Processing Record 45 of Set 11 | lazaro cardenas
# Processing Record 46 of Set 11 | bilibino
# Processing Record 47 of Set 11 | gizo
# Processing Record 48 of Set 11 | kemijarvi
# Processing Record 49 of Set 11 | radomsko
# Processing Record 50 of Set 11 | rock sound
# Processing Record 1 of Set 12 | nelson bay
# Processing Record 2 of Set 12 | queanbeyan
# Processing Record 3 of Set 12 | whitehorse
# Processing Record 4 of Set 12 | kimbe
# Processing Record 5 of Set 12 | beruni
# City not found. Skipping...
# Processing Record 6 of Set 12 | verkh-chebula
# Processing Record 7 of Set 12 | camacupa
# Processing Record 8 of Set 12 | karachi
# Processing Record 9 of Set 12 | kita
# Processing Record 10 of Set 12 | lobanovo
# Processing Record 11 of Set 12 | aborlan
# Processing Record 12 of Set 12 | jalingo
# Processing Record 13 of Set 12 | praia da vitoria
# Processing Record 14 of Set 12 | kurumkan
# Processing Record 15 of Set 12 | lompoc
# Processing Record 16 of Set 12 | termoli
# Processing Record 17 of Set 12 | boa vista
# Processing Record 18 of Set 12 | unnao
# Processing Record 19 of Set 12 | guapore
# Processing Record 20 of Set 12 | la rioja
# Processing Record 21 of Set 12 | the valley
# Processing Record 22 of Set 12 | rio gallegos
# Processing Record 23 of Set 12 | salalah
# Processing Record 24 of Set 12 | stornoway
# Processing Record 25 of Set 12 | porosozero
# Processing Record 26 of Set 12 | yerofey pavlovich
# Processing Record 27 of Set 12 | kahului
# Processing Record 28 of Set 12 | bouna
# Processing Record 29 of Set 12 | raga
# Processing Record 30 of Set 12 | pamanukan
# Processing Record 31 of Set 12 | belmonte
# Processing Record 32 of Set 12 | blagoyevo
# Processing Record 33 of Set 12 | aykhal
# Processing Record 34 of Set 12 | kieta
# Processing Record 35 of Set 12 | alice springs
# Processing Record 36 of Set 12 | langsa
# Processing Record 37 of Set 12 | bolonchen
# City not found. Skipping...
# Processing Record 38 of Set 12 | mildura
# Processing Record 39 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 40 of Set 12 | huilong
# Processing Record 41 of Set 12 | portland
# Processing Record 42 of Set 12 | jardim
# Processing Record 43 of Set 12 | placido de castro
# Processing Record 44 of Set 12 | clovis
# Processing Record 45 of Set 12 | hamilton
# Processing Record 46 of Set 12 | toyooka
# Processing Record 47 of Set 12 | mendoza
# Processing Record 48 of Set 12 | the pas
# Processing Record 49 of Set 12 | juneau
# Processing Record 50 of Set 12 | shache
# Processing Record 1 of Set 13 | sawakin
# Processing Record 2 of Set 13 | karakulino
# Processing Record 3 of Set 13 | sechura
# Processing Record 4 of Set 13 | bid
# City not found. Skipping...
# Processing Record 5 of Set 13 | fez
# Processing Record 6 of Set 13 | tari
# Processing Record 7 of Set 13 | dubrovnik
# Processing Record 8 of Set 13 | estacion coahuila
# Processing Record 9 of Set 13 | inongo
# Processing Record 10 of Set 13 | kampot
# Processing Record 11 of Set 13 | mogapi
# Processing Record 12 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 13 of Set 13 | oktyabrskoye
# Processing Record 14 of Set 13 | turan
# Processing Record 15 of Set 13 | meulaboh
# Processing Record 16 of Set 13 | dutlwe
# Processing Record 17 of Set 13 | puerto escondido
# Processing Record 18 of Set 13 | porbandar
# Processing Record 19 of Set 13 | wukari
# Processing Record 20 of Set 13 | pitimbu
# Processing Record 21 of Set 13 | dalinghe
# City not found. Skipping...
# Processing Record 22 of Set 13 | syasstroy
# Processing Record 23 of Set 13 | mizdah
# Processing Record 24 of Set 13 | oropesa
# Processing Record 25 of Set 13 | budeasa
# City not found. Skipping...
# Processing Record 26 of Set 13 | nevelsk
# Processing Record 27 of Set 13 | kamwenge
# Processing Record 28 of Set 13 | dolores
# Processing Record 29 of Set 13 | ambovombe
# Processing Record 30 of Set 13 | port keats
# Processing Record 31 of Set 13 | jaguaruana
# Processing Record 32 of Set 13 | aksay
# Processing Record 33 of Set 13 | yamada
# Processing Record 34 of Set 13 | grindavik
# Processing Record 35 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 36 of Set 13 | creel
# Processing Record 37 of Set 13 | uinskoye
# Processing Record 38 of Set 13 | almaznyy
# Processing Record 39 of Set 13 | zhigansk
# Processing Record 40 of Set 13 | teacapan
# Processing Record 41 of Set 13 | san ramon
# Processing Record 42 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 13 | mikkeli
# Processing Record 44 of Set 13 | micomeseng
# Processing Record 45 of Set 13 | manaure
# Processing Record 46 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 13 | saint-paul
# Processing Record 48 of Set 13 | macomer
# Processing Record 49 of Set 13 | babu
# Processing Record 50 of Set 13 | payo
# Processing Record 1 of Set 14 | dongsheng
# Processing Record 2 of Set 14 | bairiki
# Processing Record 3 of Set 14 | marienburg
# Processing Record 4 of Set 14 | egvekinot
# Processing Record 5 of Set 14 | ouallam
# Processing Record 6 of Set 14 | timra
# Processing Record 7 of Set 14 | caucaia
# Processing Record 8 of Set 14 | augusto correa
# Processing Record 9 of Set 14 | lazarev
# Processing Record 10 of Set 14 | sapucaia
# Processing Record 11 of Set 14 | nedjo
# Processing Record 12 of Set 14 | talavera
# Processing Record 13 of Set 14 | poplar bluff
# Processing Record 14 of Set 14 | inegol
# Processing Record 15 of Set 14 | pisco
# Processing Record 16 of Set 14 | bandarbeyla
# Processing Record 17 of Set 14 | bhasawar
# Processing Record 18 of Set 14 | lebyazhye
# Processing Record 19 of Set 14 | acarau
# Processing Record 20 of Set 14 | kobryn
# Processing Record 21 of Set 14 | ulvik
# Processing Record 22 of Set 14 | minas
# Processing Record 23 of Set 14 | yelovo
# Processing Record 24 of Set 14 | minas novas
# Processing Record 25 of Set 14 | kuala krai
# City not found. Skipping...
# Processing Record 26 of Set 14 | kindu
# Processing Record 27 of Set 14 | saint-augustin
# Processing Record 28 of Set 14 | nelson
# Processing Record 29 of Set 14 | morondava
# Processing Record 30 of Set 14 | kontagora
# Processing Record 31 of Set 14 | farafangana
# Processing Record 32 of Set 14 | maceio
# Processing Record 33 of Set 14 | cherskiy
# Processing Record 34 of Set 14 | moissala
# Processing Record 35 of Set 14 | ciudad bolivar
# Processing Record 36 of Set 14 | marrakesh
# Processing Record 37 of Set 14 | general pico
# Processing Record 38 of Set 14 | eureka
# Processing Record 39 of Set 14 | muros
# Processing Record 40 of Set 14 | ambunti
# Processing Record 41 of Set 14 | olafsvik
# Processing Record 42 of Set 14 | mosquera
# Processing Record 43 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 44 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 45 of Set 14 | wichita falls
# Processing Record 46 of Set 14 | ardea
# Processing Record 47 of Set 14 | hobyo
# Processing Record 48 of Set 14 | carutapera
# Processing Record 49 of Set 14 | bodo
# Processing Record 50 of Set 14 | kondinskoye
# Processing Record 1 of Set 15 | itacare
# Processing Record 2 of Set 15 | kitimat
# Processing Record 3 of Set 15 | tvedestrand
# Processing Record 4 of Set 15 | verkhnyaya inta
# Processing Record 5 of Set 15 | katsuura
# Processing Record 6 of Set 15 | prieska
# Processing Record 7 of Set 15 | killam
# Processing Record 8 of Set 15 | aswan
# Processing Record 9 of Set 15 | evensk
# Processing Record 10 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 11 of Set 15 | sobolevo
# Processing Record 12 of Set 15 | lagos
# Processing Record 13 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 14 of Set 15 | tanout
# Processing Record 15 of Set 15 | astara
# Processing Record 16 of Set 15 | sangmelima
# Processing Record 17 of Set 15 | mayo
# Processing Record 18 of Set 15 | miles city
# Processing Record 19 of Set 15 | libreville
# Processing Record 20 of Set 15 | semey
# Processing Record 21 of Set 15 | clemencia
# Processing Record 22 of Set 15 | mnogovershinnyy
# Processing Record 23 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 24 of Set 15 | nyimba
# Processing Record 25 of Set 15 | koulamoutou
# Processing Record 26 of Set 15 | marfino
# Processing Record 27 of Set 15 | namatanai
# Processing Record 28 of Set 15 | manokwari
# Processing Record 29 of Set 15 | tambo grande
# Processing Record 30 of Set 15 | mahanoro
# Processing Record 31 of Set 15 | shuangcheng
# Processing Record 32 of Set 15 | bulawayo
# Processing Record 33 of Set 15 | trofors
# Processing Record 34 of Set 15 | ulladulla
# Processing Record 35 of Set 15 | kedarnath
# City not found. Skipping...
# Processing Record 36 of Set 15 | poya
# Processing Record 37 of Set 15 | presidente dutra
# Processing Record 38 of Set 15 | tabou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 683

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Juba      SS   4.85   31.58     84.61        55          63
# 1    Hithadhoo      MV  -0.60   73.08     83.01        77         100
# 2  Grand-Santi      GF   4.25  -54.38     71.69        96          35
# 3       Osmena      PH  10.52  119.93     85.21        74           7
# 4   Bredasdorp      ZA -34.53   20.04     68.00        56          57
# 5      Ushuaia      AR -54.80  -68.30     33.80        80          40
# 6     Klaksvik      FO  62.23   -6.59     42.80        75          98
# 7      Kamenka      RU  51.32   42.77     48.99        59          14
# 8      Boyabat      TR  41.47   34.77     64.40        93          75
# 9       Bethel      US  41.37  -73.41     46.00        93           1
#
#    Wind Speed Current Description
# 0        5.35       broken clouds
# 1       14.47     overcast clouds
# 2        2.68    scattered clouds
# 3        9.95           clear sky
# 4        3.36       broken clouds
# 5       35.57    scattered clouds
# 6       10.29          light rain
# 7        8.86          few clouds
# 8       13.87       broken clouds
# 9        1.92           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
